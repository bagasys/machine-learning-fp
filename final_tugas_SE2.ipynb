# %%
import pandas as pd
df = pd.read_csv("bank-full.csv")
inputs = df.drop(['y'],axis='columns')
target = df['y']

# %%
from sklearn.preprocessing import LabelEncoder
lb = LabelEncoder()
for col in inputs.columns:
    inputs[col]= lb.fit_transform(inputs[col])

# inputs['y'] = target
# inputs.head(20)

# %%
from sklearn import tree
from sklearn.naive_bayes import MultinomialNB
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import train_test_split

x_train, x_test, y_train, y_test = train_test_split(inputs,target)

# %%
dec_tree = tree.DecisionTreeClassifier()
dec_tree.fit(x_train,y_train)
dec_tree.score(x_test,y_test) * 100
# Out:
# 87.22463062903654

# %%
naive_bayes = MultinomialNB()
naive_bayes.fit(x_train,y_train)
naive_bayes.score(x_test,y_test) * 100
# Out:
# 67.38034150225603

# %%
knn = KNeighborsClassifier(n_neighbors=3)
knn.fit(x_train,y_train)
knn.score(x_test,y_test) * 100
# Out:
# 87.5165885163231

# %%
dec_tree_pred = dec_tree.predict(inputs)
naive_bayes_pred = naive_bayes.predict(inputs)
knn_pred = knn.predict(inputs)

# %%
df = pd.DataFrame(inputs)
df['Y'] = target
df['Dec Tree'] = dec_tree_pred
df['Naive Bayes'] = naive_bayes_pred
df['KNN'] = knn_pred

# %%
df
# Out:
#        age  job  marital  education  default  balance  housing  loan  contact  \
# 0       40    4        1          2        0     3036        1     0        2
# 1       26    9        2          1        0      945        1     0        2
# 2       15    2        1          1        0      918        1     1        2
# 3       29    1        1          3        0     2420        1     0        2
# 4       15   11        2          3        0      917        0     0        2
# 5       17    4        1          2        0     1147        1     0        2
# 6       10    4        2          2        0     1363        1     1        2
# 7       24    2        0          2        1      918        1     0        2
# 8       40    5        1          0        0     1037        1     0        2
# 9       25    9        2          1        0     1509        1     0        2
# 10      23    0        0          1        0     1186        1     0        2
# 11      11    0        2          1        0     1306        1     0        2
# 12      35    9        1          1        0      922        1     0        2
# 13      40    9        1          3        0      987        1     0        2
# 14      39    7        1          1        0     1078        1     0        2
# 15      33    5        1          0        0     1145        1     0        2
# 16      27    0        2          3        0      929        1     0        2
# 17      39    1        1          0        0      968        1     0        2
# 18      42    5        1          0        0      976        1     0        2
# 19      15    7        1          1        0      916        1     0        2
# 20      10    1        1          1        0     1639        1     1        2
# 21      38    4        1          2        0     1695        1     0        2
# 22      14    1        2          0        0      939        1     1        2
# 23       7    7        1          1        0      966        1     0        2
# 24      22    5        1          0        0      916        1     1        2
# 25      26    0        1          1        0      547        1     0        2
# 26      21    4        2          2        0     1171        1     0        2
# 27      34    2        1          1        0     1029        1     1        2
# 28      28    4        2          1        0      670        1     0        2
# 29      18    9        2          1        0     1181        1     1        2
# ...    ...  ...      ...        ...      ...      ...      ...   ...      ...
# 45181   28    1        1          1        0     5863        0     0        0
# 45182   16    9        1          1        0     1049        0     0        0
# 45183   52    5        1          0        0     1240        0     0        0
# 45184   45    5        1          1        0     2410        0     0        0
# 45185   42    7        1          2        0     4701        1     0        0
# 45186   41   11        1          3        0     2415        0     0        0
# 45187   14    7        2          1        0     2084        1     0        0
# 45188   11    4        2          1        0     1619        1     0        0
# 45189    7    7        2          1        0     1115        0     0        0
# 45190   14    1        1          1        0     1052        0     0        0
# 45191   57    5        0          2        0     4422        1     0        0
# 45192   11    4        2          2        0     1681        0     0        0
# 45193   10    6        2          2        0     1075        0     0        0
# 45194   41    4        1          2        0     1054        1     1        0
# 45195   50    5        1          1        0     2062        0     0        0
# 45196    7    8        2          1        0     1274        0     0        0
# 45197   18    4        2          1        0     2425        1     0        0
# 45198   19    4        1          2        0     2344        0     0        0
# 45199   16    1        2          1        0     2391        1     0        0
# 45200   20    9        1          1        0     1473        1     0        0
# 45201   35    4        1          2        0     1499        0     0        0
# 45202   16    0        2          1        0     1473        0     0        0
# 45203    5    8        2          2        0     1029        0     0        0
# 45204   55    5        1          1        0     3678        0     0        0
# 45205    7    9        2          1        0     1421        0     1        0
# 45206   33    9        1          2        0     1741        0     0        0
# 45207   53    5        0          0        0     2639        0     0        0
# 45208   54    5        1          1        0     5455        0     0        0
# 45209   39    1        1          1        0     1584        0     0        1
# 45210   19    2        1          1        0     3779        0     0        0
#
#        day  month  duration  campaign  pdays  previous  poutcome    Y  \
# 0        4      8       261         0      0         0         3   no
# 1        4      8       151         0      0         0         3   no
# 2        4      8        76         0      0         0         3   no
# 3        4      8        92         0      0         0         3   no
# 4        4      8       198         0      0         0         3   no
# 5        4      8       139         0      0         0         3   no
# 6        4      8       217         0      0         0         3   no
# 7        4      8       380         0      0         0         3   no
# 8        4      8        50         0      0         0         3   no
# 9        4      8        55         0      0         0         3   no
# 10       4      8       222         0      0         0         3   no
# 11       4      8       137         0      0         0         3   no
# 12       4      8       517         0      0         0         3   no
# 13       4      8        71         0      0         0         3   no
# 14       4      8       174         0      0         0         3   no
# 15       4      8       353         0      0         0         3   no
# 16       4      8        98         0      0         0         3   no
# 17       4      8        38         0      0         0         3   no
# 18       4      8       219         0      0         0         3   no
# 19       4      8        54         0      0         0         3   no
# 20       4      8       262         0      0         0         3   no
# 21       4      8       164         0      0         0         3   no
# 22       4      8       160         0      0         0         3   no
# 23       4      8       342         0      0         0         3   no
# 24       4      8       181         0      0         0         3   no
# 25       4      8       172         0      0         0         3   no
# 26       4      8       296         0      0         0         3   no
# 27       4      8       127         0      0         0         3   no
# 28       4      8       255         1      0         0         3   no
# 29       4      8       348         0      0         0         3   no
# ...    ...    ...       ...       ...    ...       ...       ...  ...
# 45181   14      9        74         1    115         3         0   no
# 45182   14      9       401         1    184         5         2  yes
# 45183   14      9        78         0     93         7         2   no
# 45184   15      9       138         0     20         5         2   no
# 45185   15      9       200         0     89         4         2  yes
# 45186   15      9       280         0    101         2         0   no
# 45187   15      9       411         0      0         0         3  yes
# 45188   15      9       236         0    495         2         2  yes
# 45189   15      9       173         0     89         5         0   no
# 45190   15      9       206         0    185         3         2  yes
# 45191   15      9       262         0    180         1         0  yes
# 45192   15      9       238         0      0         0         3  yes
# 45193   15      9       449         1     30         4         2  yes
# 45194   15      9       162         1    184         5         0   no
# 45195   15      9       212         0    184         6         2  yes
# 45196   15      9       330         0      0         0         3  yes
# 45197   15      9       270         0      0         0         3  yes
# 45198   15      9       333         1      0         0         3   no
# 45199   15      9      1151         2    485        12         1   no
# 45200   15      9      1403         3      0         0         3  yes
# 45201   16      9       226         0    181         4         2  yes
# 45202   16      9       224         0      0         0         3  yes
# 45203   16      9       266         0      0         0         3  yes
# 45204   16      9       300         0     37         8         0  yes
# 45205   16      9       386         1      0         0         3  yes
# 45206   16      9       975         2      0         0         3  yes
# 45207   16      9       456         1      0         0         3  yes
# 45208   16      9      1116         4    181         3         2  yes
# 45209   16      9       508         3      0         0         3   no
# 45210   16      9       361         1    185        11         1   no
#
#       Dec Tree Naive Bayes  KNN
# 0           no          no   no
# 1           no          no   no
# 2           no          no   no
# 3           no          no   no
# 4           no         yes   no
# 5           no          no   no
# 6           no          no   no
# 7           no         yes   no
# 8           no          no   no
# 9           no          no   no
# 10          no          no   no
# 11          no          no   no
# 12          no         yes   no
# 13          no          no   no
# 14          no          no   no
# 15          no         yes   no
# 16          no          no   no
# 17          no          no   no
# 18          no         yes   no
# 19          no          no   no
# 20          no          no   no
# 21          no          no   no
# 22          no          no   no
# 23          no         yes   no
# 24          no         yes   no
# 25          no         yes   no
# 26          no         yes   no
# 27          no          no   no
# 28          no         yes   no
# 29          no         yes   no
# ...        ...         ...  ...
# 45181       no          no   no
# 45182      yes         yes  yes
# 45183       no          no   no
# 45184       no          no   no
# 45185      yes          no   no
# 45186       no          no   no
# 45187      yes         yes   no
# 45188      yes         yes   no
# 45189       no         yes  yes
# 45190      yes         yes  yes
# 45191      yes          no  yes
# 45192      yes          no   no
# 45193      yes         yes   no
# 45194       no         yes   no
# 45195      yes          no   no
# 45196      yes         yes   no
# 45197       no          no   no
# 45198       no          no   no
# 45199       no         yes  yes
# 45200      yes         yes  yes
# 45201      yes         yes  yes
# 45202      yes          no   no
# 45203      yes         yes   no
# 45204      yes          no   no
# 45205      yes         yes   no
# 45206      yes         yes  yes
# 45207      yes          no   no
# 45208      yes         yes  yes
# 45209       no         yes   no
# 45210       no          no   no
#
# [45211 rows x 20 columns]
